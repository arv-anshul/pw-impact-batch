# %%
import math

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Q1. What is the Probability density function?

# %% [markdown]
# The **Probability Density Function (PDF)** is a function used in statistics to describe the relative likelihood of a random variable taking on a certain value. In other words, it is a function that describes the probability distribution of a continuous random variable.
#
# The PDF is denoted by **f(x)** and is defined as the _derivative of the **Cumulative Distribution Function (CDF)**_ of the random variable X.
#
# The PDF has several important properties, including:
#
# 1. **Non-negativity:** f(x) is always non-negative, meaning that the probability of X taking on any value cannot be negative.
# 2. **Normalization:** The area under the curve of f(x) must be equal to 1, since the probability of X taking on any value must be 1.
# 3. **Integration:** The probability of X taking on a value within a certain range is given by the area under the curve of f(x) over that range.

# %% [markdown]
# ### Q2. What are the types of Probability distribution?

# %% [markdown]
# - **Normal Distribution:** The normal distribution is a bell-shaped, continuous distribution that is often used to model naturally occurring phenomena, such as height or weight. It is characterized by its mean (μ) and standard deviation (σ), which determine the shape and location of the distribution.
#
# - **Binomial Distribution:** The binomial distribution is a discrete probability distribution that models the number of successes in a fixed number of independent trials. It is characterized by two parameters: the probability of success (p) and the number of trials (n).
#
# - **Poisson Distribution:** The Poisson distribution is a discrete probability distribution that models the number of events that occur in a fixed interval of time or space. It is characterized by one parameter, λ, which represents the average number of events that occur in the interval.
#
# - **Uniform Distribution:** The uniform distribution is a continuous probability distribution that models outcomes that are equally likely to occur within a given range. It is characterized by two parameters: the minimum and maximum values of the range.

# %% [markdown]
# ### Q3. Write a Python function to calculate the probability density function of a normal distribution with given mean and standard deviation at a given point.

# %%
# Creating a series of data of in range of 1-50.
x = np.linspace(1, 50, 200)


def normal_dist(x, mean, std):
    prob_density = (np.pi*std) * np.exp(-0.5*((x-mean)/std)**2)
    return prob_density


# Calculate mean and Standard deviation.
mean = np.mean(x)
std = np.std(x)

# Apply function to the data.
pdf = normal_dist(x, mean, std)

# Plotting the Results
plt.plot(x, pdf)
plt.xlabel('Data points')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %% [markdown]
# ### Q4. What are the properties of Binomial distribution? Give two examples of events where binomial distribution can be applied.

# %% [markdown]
# Binomial distribution is a probability distribution that describes the number of successes in a fixed number of independent trials. The properties of a binomial distribution are:
#
# 1. The experiment consists of a fixed number of trials, say n.
# 1. The trials are independent and identical.
# 1. Each trial has only two possible outcomes, either a success or a failure.
# 1. The probability of success remains constant throughout all trials.
# 1. The random variable X, which represents the number of successes, follows a binomial distribution with parameters n and p.
#
# Two examples of events where the binomial distribution can be applied are:
#
# 1. **Coin Tossing:** If we toss a coin n times and count the number of heads, then the number of heads follows a binomial distribution.
# 1. **Quality Control:** In manufacturing, if we inspect n products and count the number of defective products, then the number of defective products follows a binomial distribution.

# %% [markdown]
# ### Q5. Generate a random sample of size 1000 from a binomial distribution with probability of success 0.4 and plot a histogram of the results using matplotlib.

# %%
# Generate random sample of size 1000 from binomial distribution with p=0.4
n = 10
p = 0.4
sample = np.random.binomial(n, p, 1000)

s = pd.Series(sample)
s.value_counts()
# Out:
# 4    263
# 3    205
# 5    181
# 2    118
# 6    117
# 1     45
# 7     43
# 8     16
# 0      9
# 9      3
# dtype: int64

# %%
s.value_counts(True).sort_index()
# Out:
# 0    0.009
# 1    0.045
# 2    0.118
# 3    0.205
# 4    0.263
# 5    0.181
# 6    0.117
# 7    0.043
# 8    0.016
# 9    0.003
# dtype: float64

# %%
# Plot histogram of the results
plt.hist(s, bins=range(n+2), align='left', rwidth=0.8)
plt.xticks(range(n+1))
plt.xlabel('Number of successes')
plt.ylabel('Frequency')
plt.title('Binomial Distribution with n=10, p=0.4')
plt.show()

# %% [markdown]
# ### Q6. Write a Python function to calculate the cumulative distribution function of a Poisson distribution with given mean at a given point.

# %%
def poisson_cdf(mean, k):
    cdf = 0
    for i in range(k+1):
        cdf += (math.exp(-mean) * mean**i) / math.factorial(i)
    return cdf

mean = 2.5
k = 3
cdf = poisson_cdf(mean, k)
print(cdf)
# Out:
# 0.7575761331330659

# %%
p = np.random.poisson(3, 1000)

poisson = pd.Series(p)
poisson.value_counts().sort_index()
# Out:
# 0     50
# 1    144
# 2    200
# 3    256
# 4    174
# 5    100
# 6     42
# 7     20
# 8     12
# 9      2
# dtype: int64

# %%
poisson.value_counts().sort_index().cumsum()
# Out:
# 0      50
# 1     194
# 2     394
# 3     650
# 4     824
# 5     924
# 6     966
# 7     986
# 8     998
# 9    1000
# dtype: int64

# %%
poisson.value_counts().sort_index().cumsum().plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Q7. How Binomial distribution different from Poisson distribution?

# %% [markdown]
# **Binomial distribution** is used to model the number of successes in a fixed number of independent trials with a constant probability of success. The distribution is characterized by two parameters, the number of trials (n) and the probability of success (p).
#
# **Poisson distribution**, on the other hand, is used to model the number of events in a fixed interval of time or space. It is characterized by a single parameter, the mean number of events (λ) in the given interval.

# %% [markdown]
# ### Q8. Generate a random sample of size 1000 from a Poisson distribution with mean 5 and calculate the sample mean and variance.

# %%
sample = np.random.poisson(5, 1000) # generate random sample
sample_mean = np.mean(sample) # calculate sample mean
sample_var = np.var(sample) # calculate sample variance

print("Sample Mean:", sample_mean)
print("Sample Variance:", sample_var)
# Out:
# Sample Mean: 4.985
# Sample Variance: 5.062774999999999

# %% [markdown]
# The _sample mean_ and _variance_ are likely to be close to their theoretical values of 5.

# %% [markdown]
# ### Q9. How mean and variance are related in Binomial distribution and Poisson distribution?

# %% [markdown]
# In a **Binomial distribution**, the mean and variance are related by the formula:
#
# $ \bar{x} = n * p $
# $ \sigma = n * p * (1 - p) $
#
# Where $n$ is the number of trials and $p$ is the probability of success in each trial.
#
# In a **Poisson distribution**, the mean and variance are equal and both are denoted by $\lambda$. The formula for the mean and variance is:
#
# $ \bar{x} = \lambda $
# $ \sigma = \lambda $

# %% [markdown]
# ### Q10. In normal distribution with respect to mean position, where does the least frequent data appear?
#
# In a **normal distribution**, the data is clustered near the mean becomes less frequent as it moves away from the mean. Therefore, _the least frequent data appears in the tails of the distribution_, which are the extreme ends.
